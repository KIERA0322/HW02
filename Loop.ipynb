# %%
#Loop de loop (hopefully not forever)
Golf = range(5,10)

for n in Golf:
    print(n)

print(f"\n{Golf[1]}")
# Out:
# 5
# 6
# 7
# 8
# 9
#
# 6

# %%
i=0
while i <= 99:
    i=i+4
    print(i)
# Out:
# 4
# 8
# 12
# 16
# 20
# 24
# 28
# 32
# 36
# 40
# 44
# 48
# 52
# 56
# 60
# 64
# 68
# 72
# 76
# 80
# 84
# 88
# 92
# 96
# 100

# %%
#CNTRL+C is break glass in case of emergency.
