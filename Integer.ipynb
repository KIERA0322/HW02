# %%
import random

# %%
#INTEGERS!!!!
#From the reading I have been doing, python will automatically define each variable as the most efficient data type. It feels foreign to me
#to define variables without defining thier datatypes, but here goes:
Jack_Daniels = 92
print(type(Jack_Daniels))
# Out:
# <class 'int'>

# %%
#Strings can be converted to integers!
Levi_Jeans = "1329"
print(type(Levi_Jeans))
Levi_Jeans = int(Levi_Jeans) #Convert Levi_Jeans from any data type to an integer
print(type(Levi_Jeans))
# Out:
# <class 'str'>
# <class 'int'>

# %%
#Random numbers can be generated as integers!
Harley_Davidson = random.randint(1,10)
print(type(Harley_Davidson))
print(Harley_Davidson)
# Out:
# <class 'int'>
# 4
