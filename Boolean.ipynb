# %%
#Booleans
Rich_May = True
if Rich_May:
    print("truth nuke")
# Out:
# Truth nuke

# %%
#If statments can be channeled through true or false values.
Georgia = False
if Georgia:
    How are you reading this?
else:
    print("false nuke")
# Out:
# false nuke

# %%
#Im gonna play around with this for a bit
if ('982' < 'a'):
    print('True!')
else:
    print('Nope try again')
# Out:
# True!

# %%
#Total truth!
